# %%
import dplpy as dpl
data = dpl.readers("../tests/data/rwl/co021.rwl")
# Out:
# Attempting to read input file: co021.rwl as .rwl format
#
#
# SUCCESS!
# File read as: .rwl file
#
# Series names:
# ['641114', '641121', '641132', '641143', '642114', '642121', '642143', '642211', '642222', '642233', '642244', '643114', '643143', '643211', '643222', '643233', '643244', '644143', '644211', '644222', '644233', '644244', '645100', '645102', '645103', '645214', '645221', '645232', '645243', '646107', '646118', '646211', '646222', '646233', '646244']

# %%
dpl.detrend(data['641114'], "ModNegEx", "difference")
# Out:
# array([ 3.91262510e-01,  1.25739618e+00,  2.63230309e-01, -3.71229545e-01,
#        -2.05977924e-01,  2.08990531e-01, -4.76318925e-01, -4.11901130e-01,
#        -5.67751022e-01, -3.03863629e-01, -6.10234075e-01, -1.66857572e-01,
#        -1.83729422e-01, -5.00845015e-01, -2.48199823e-01, -4.45789407e-01,
#        -6.36094078e-02, -1.41655546e-01, -3.99236249e-02,  5.41590478e-01,
#         7.22890805e-01,  2.13981326e-01, -2.35134063e-01, -4.45153972e-03,
#         6.60326478e-02, -5.43677818e-01, -3.33579323e-01, -1.63668320e-01,
#         1.06058671e-01, -3.04394932e-01, -4.50257778e-02,  2.74169426e-01,
#         3.73193908e-01,  5.32050838e-01, -5.92566729e-02,  4.29274428e-01,
#        -5.23528619e-02, -3.34135603e-01, -3.26070909e-01,  4.91844054e-01,
#         3.69612064e-01,  1.87235850e-01,  4.04718091e-01,  8.42061413e-01,
#         5.92683969e-02,  2.76341573e-01, -4.86716574e-01,  4.00963942e-02,
# ...
