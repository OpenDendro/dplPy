# %%
import dplpy as dpl
data = dpl.readers("../tests/data/rwl/co021.rwl")
# Out:
# Attempting to read input file: co021.rwl as .rwl format
#
#
# SUCCESS!
# File read as: .rwl file

# %%
dpl.detrend(data)
# Out:
# Detrending with Cubic smoothing spline
#                             AutoReg Model Results
# ...
# Dep. Variable:                 641114   No. Observations:                  694
# Model:                     AutoReg(4)   Log Likelihood                 363.027
# Method:               Conditional MLE   S.D. of innovations              0.143
# Date:                Wed, 25 May 2022   AIC                             -3.873
# Time:                        15:36:42   BIC                             -3.833
# Sample:                             4   HQIC                            -3.857
#                                   694
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0509      0.010      5.135      0.000       0.031       0.070
# 641114.L1      0.4071      0.037     11.002      0.000       0.335       0.480
# ...
